# %% [markdown]
# # Problem Statement: The objective of this project is to develop a machine learning model to predict stock price movements or target a specific column like Close (which is often the predicted value in stock-related data).

# %% [markdown]
# # Data Preprocessing

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
 # Load the dataset
data=pd.read_csv("World-Stock-Prices-Dataset.csv")
data
# Out:
#                              Date        Open        High         Low  \
# 0       2024-10-04 00:00:00-04:00    4.790000    4.885000    4.600000
# 1       2024-10-04 00:00:00-04:00  140.860001  142.740005  140.279999
# 2       2024-10-04 00:00:00-04:00   69.959999   70.279999   69.720001
# 3       2024-10-04 00:00:00-04:00  713.320007  721.010010  708.820007
# 4       2024-10-04 00:00:00-04:00   24.400000   24.900000   23.990000
# ...                           ...         ...         ...         ...
# 296750  2000-01-03 00:00:00-05:00   34.729481   34.729481   32.934947
# 296751  2000-01-03 00:00:00-05:00   22.361069   22.431057   21.801168
# 296752  2000-01-03 00:00:00-05:00   11.826695   11.850113   11.405149
# 296753  2000-01-03 00:00:00-05:00    4.075000    4.478125    3.952344
# 296754  2000-01-03 00:00:00-05:00    5.731675    5.793975    5.427959
#
#              Close       Volume  Dividends  Stock Splits  \
# 0         4.700000   13553417.0        0.0           0.0
# 1       141.929993     813600.0        0.0           0.0
# 2        70.169998   12684800.0        0.0           0.0
# 3       719.700012    2229000.0        0.0           0.0
# 4        24.110001    2774500.0        0.0           0.0
# ...            ...          ...        ...           ...
# 296750   33.198849    6471267.0        0.0           0.0
# 296751   22.186100    4520600.0        0.0           0.0
# 296752   11.428568    2506717.0        0.0           0.0
# 296753    4.468750  322352000.0        0.0           0.0
# 296754    5.482471    5825700.0        0.0           0.0
#
#                        Brand_Name Ticker     Industry_Tag Country  \
# 0                         peloton   PTON          fitness     usa
# 1                           crocs   CROX         footwear     usa
# 2           the coca-cola company     KO  food & beverage     usa
# 3                         netflix   NFLX    entertainment     usa
# 4                     foot locker     FL         footwear     usa
# ...                           ...    ...              ...     ...
# 296750           american express    AXP          finance     usa
# 296751                 mcdonald's    MCD             food     usa
# 296752                   marriott    MAR      hospitality     usa
# 296753                     amazon   AMZN       e-commerce     usa
# 296754  american eagle outfitters    AEO          apparel     usa
#
#         Capital Gains
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 296750            NaN
# 296751            NaN
# 296752            NaN
# 296753            NaN
# 296754            NaN
#
# [296755 rows x 13 columns]

# %%
#Finding the information of dataframe
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 296755 entries, 0 to 296754
# Data columns (total 13 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           296755 non-null  object
#  1   Open           296755 non-null  float64
#  2   High           296755 non-null  float64
#  3   Low            296755 non-null  float64
#  4   Close          296755 non-null  float64
#  5   Volume         296755 non-null  float64
#  6   Dividends      296755 non-null  float64
#  7   Stock Splits   296755 non-null  float64
#  8   Brand_Name     296755 non-null  object
#  9   Ticker         296755 non-null  object
#  10  Industry_Tag   296755 non-null  object
#  11  Country        296755 non-null  object
#  12  Capital Gains  2 non-null       float64
# dtypes: float64(8), object(5)
# memory usage: 29.4+ MB

# %%
# Dropping the column 'Capital Gains' that would not help me in my prediction purpose
data_cleaned = data.drop(['Capital Gains'], axis=1,inplace=True)

# %%
# Check for missing values
data.isnull().sum()
# Out:
# Date            0
# Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# Dividends       0
# Stock Splits    0
# Brand_Name      0
# Ticker          0
# Industry_Tag    0
# Country         0
# dtype: int64

# %% [markdown]
# # Column Names and its Descriptions

# %% [raw]
# Open, High, Low, Close, Volume: Typical stock market indicators (numerical data)
# Dividends, Stock Splits: Stock-related features (numerical data)
# Brand_Name, Ticker, Industry_Tag, Country: Categorical data providing company, stock ticker, industry, and country

# %%
#Descriptive Statistics of dataframe
data.describe()
# Out:
#                 Open           High            Low          Close  \
# count  296755.000000  296755.000000  296755.000000  296755.000000
# mean       71.685970      72.497539      70.853581      71.693850
# std       136.759681     138.221655     135.201411     136.736214
# min         0.196890       0.199922       0.192798       0.198861
# 25%        15.539100      15.747868      15.316266      15.540000
# 50%        34.060200      34.469150      33.665442      34.072231
# 75%        78.343005      79.110613      77.611071      78.358852
# max      3445.580078    3463.070068    3370.000000    3427.610107
#
#              Volume      Dividends   Stock Splits
# count  2.967550e+05  296755.000000  296755.000000
# mean   2.309856e+07       0.003592       0.000914
# std    8.719560e+07       0.069749       0.118005
# min    0.000000e+00       0.000000       0.000000
# 25%    1.360400e+06       0.000000       0.000000
# 50%    4.594300e+06       0.000000       0.000000
# 75%    1.219435e+07       0.000000       0.000000
# max    7.421641e+09      15.000000      50.000000

# %% [markdown]
# # Graphs

# %%
# sns.set()
# plt.figure(figsize=(6,6))
# sns.countplot(data['Open'])
# plt.title('Open Prices Distribution')
# plt.show()

# %%
# plt.figure(figsize=(5,5))
# sns.distplot(x='Open',d=data)
# plt.title('Distribution of Open')
# plt.show()

# %%
# plt.figure(figsize=(5,5))
# sns.lineplot(x='High',d=data)
# plt.title('Distribution of High')
# plt.show()

# %%
# plt.figure(figsize=(5,5))
# sns.countplot(x='Low',d=data)
# plt.title('Distribution of Low')
# # plt.show()

# %%
# plt.figure(figsize=(5,5))
# sns.distplot(x='Volume',x=data)
# # plt.title('Distribution of Volume')
# plt.show()

# %%
# plt.figure(figsize=(5,5))
# sns.countplot(x='Dividends',d=data)
# plt.title('Distribution of Dividends')
# plt.show()

# %% [markdown]
# # Splitting Features(X) and Target(Y)

# %%
X = data.drop('Close', axis=1)  # Features
y = data['Close']  # Target

# %%
X
# Out:
#                              Date        Open        High         Low  \
# 0       2024-10-04 00:00:00-04:00    4.790000    4.885000    4.600000
# 1       2024-10-04 00:00:00-04:00  140.860001  142.740005  140.279999
# 2       2024-10-04 00:00:00-04:00   69.959999   70.279999   69.720001
# 3       2024-10-04 00:00:00-04:00  713.320007  721.010010  708.820007
# 4       2024-10-04 00:00:00-04:00   24.400000   24.900000   23.990000
# ...                           ...         ...         ...         ...
# 296750  2000-01-03 00:00:00-05:00   34.729481   34.729481   32.934947
# 296751  2000-01-03 00:00:00-05:00   22.361069   22.431057   21.801168
# 296752  2000-01-03 00:00:00-05:00   11.826695   11.850113   11.405149
# 296753  2000-01-03 00:00:00-05:00    4.075000    4.478125    3.952344
# 296754  2000-01-03 00:00:00-05:00    5.731675    5.793975    5.427959
#
#              Volume  Dividends  Stock Splits                 Brand_Name  \
# 0        13553417.0        0.0           0.0                    peloton
# 1          813600.0        0.0           0.0                      crocs
# 2        12684800.0        0.0           0.0      the coca-cola company
# 3         2229000.0        0.0           0.0                    netflix
# 4         2774500.0        0.0           0.0                foot locker
# ...             ...        ...           ...                        ...
# 296750    6471267.0        0.0           0.0           american express
# 296751    4520600.0        0.0           0.0                 mcdonald's
# 296752    2506717.0        0.0           0.0                   marriott
# 296753  322352000.0        0.0           0.0                     amazon
# 296754    5825700.0        0.0           0.0  american eagle outfitters
#
#        Ticker     Industry_Tag Country
# 0        PTON          fitness     usa
# 1        CROX         footwear     usa
# 2          KO  food & beverage     usa
# 3        NFLX    entertainment     usa
# 4          FL         footwear     usa
# ...       ...              ...     ...
# 296750    AXP          finance     usa
# 296751    MCD             food     usa
# 296752    MAR      hospitality     usa
# 296753   AMZN       e-commerce     usa
# 296754    AEO          apparel     usa
#
# [296755 rows x 11 columns]

# %%
y
# Out:
# 0           4.700000
# 1         141.929993
# 2          70.169998
# 3         719.700012
# 4          24.110001
#              ...
# 296750     33.198849
# 296751     22.186100
# 296752     11.428568
# 296753      4.468750
# 296754      5.482471
# Name: Close, Length: 296755, dtype: float64

# %%
print(X.columns)
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Volume', 'Dividends', 'Stock Splits',
#        'Brand_Name', 'Ticker', 'Industry_Tag', 'Country'],
#       dtype='object')

# %% [markdown]
# # Encoding the Categorical Features Numerical using Ordinal Encoder

# %%
cat_col=X.select_dtypes(object).columns

# %%
X[cat_col]
# Out:
#                              Date                 Brand_Name Ticker  \
# 0       2024-10-04 00:00:00-04:00                    peloton   PTON
# 1       2024-10-04 00:00:00-04:00                      crocs   CROX
# 2       2024-10-04 00:00:00-04:00      the coca-cola company     KO
# 3       2024-10-04 00:00:00-04:00                    netflix   NFLX
# 4       2024-10-04 00:00:00-04:00                foot locker     FL
# ...                           ...                        ...    ...
# 296750  2000-01-03 00:00:00-05:00           american express    AXP
# 296751  2000-01-03 00:00:00-05:00                 mcdonald's    MCD
# 296752  2000-01-03 00:00:00-05:00                   marriott    MAR
# 296753  2000-01-03 00:00:00-05:00                     amazon   AMZN
# 296754  2000-01-03 00:00:00-05:00  american eagle outfitters    AEO
#
#            Industry_Tag Country
# 0               fitness     usa
# 1              footwear     usa
# 2       food & beverage     usa
# 3         entertainment     usa
# 4              footwear     usa
# ...                 ...     ...
# 296750          finance     usa
# 296751             food     usa
# 296752      hospitality     usa
# 296753       e-commerce     usa
# 296754          apparel     usa
#
# [296755 rows x 5 columns]

# %%
from sklearn.preprocessing import OrdinalEncoder
oe=OrdinalEncoder()
X[cat_col]=oe.fit_transform(X[cat_col])

# %%
X[cat_col]
# Out:
#           Date  Brand_Name  Ticker  Industry_Tag  Country
# 0       6227.0        37.0    46.0           9.0      6.0
# 1       6227.0        16.0    14.0          12.0      6.0
# 2       6227.0        51.0    28.0          11.0      6.0
# 3       6227.0        32.0    37.0           6.0      6.0
# 4       6227.0        19.0    19.0          12.0      6.0
# ...        ...         ...     ...           ...      ...
# 296750     0.0         7.0     7.0           7.0      6.0
# 296751     0.0        30.0    34.0          10.0      6.0
# 296752     0.0        28.0    33.0          15.0      6.0
# 296753     0.0         4.0     6.0           5.0      6.0
# 296754     0.0         6.0     4.0           0.0      6.0
#
# [296755 rows x 5 columns]

# %%
X.head()
# Out:
#      Date        Open        High         Low      Volume  Dividends  \
# 0  6227.0    4.790000    4.885000    4.600000  13553417.0        0.0
# 1  6227.0  140.860001  142.740005  140.279999    813600.0        0.0
# 2  6227.0   69.959999   70.279999   69.720001  12684800.0        0.0
# 3  6227.0  713.320007  721.010010  708.820007   2229000.0        0.0
# 4  6227.0   24.400000   24.900000   23.990000   2774500.0        0.0
#
#    Stock Splits  Brand_Name  Ticker  Industry_Tag  Country
# 0           0.0        37.0    46.0           9.0      6.0
# 1           0.0        16.0    14.0          12.0      6.0
# 2           0.0        51.0    28.0          11.0      6.0
# 3           0.0        32.0    37.0           6.0      6.0
# 4           0.0        19.0    19.0          12.0      6.0

# %%
print(X.shape)
# Out:
# (296755, 11)

# %% [markdown]
# # Splitting the Data into Training & Testing data

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.10,random_state=42)

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (267079, 11) (29676, 11) (267079,) (29676,)

# %%
X_train.head()
# Out:
#           Date        Open        High         Low     Volume  Dividends  \
# 42526   5550.0  148.555953  149.452393  143.771680   233700.0        0.0
# 289330   218.0   12.876318   12.876318   12.682604    29600.0        0.0
# 43936   5527.0  206.323601  206.994612  204.123110  9434400.0        0.0
# 166199  3230.0   24.855862   25.049168   24.823644   260600.0        0.0
# 295974    22.0    5.872227    5.965437    5.856692  1426500.0        0.0
#
#         Stock Splits  Brand_Name  Ticker  Industry_Tag  Country
# 42526            0.0        27.0    31.0          17.0      1.0
# 289330           0.0        23.0    23.0           1.0      3.0
# 43936            0.0        58.0    58.0           7.0      6.0
# 166199           0.0        23.0    23.0           1.0      3.0
# 295974           0.0        57.0    57.0           3.0      4.0

# %% [markdown]
# # Model Training

# %%
# step-1: Import the model
from sklearn.linear_model import LinearRegression

#Step-2: Create the instance of the model
lr=LinearRegression()

#Step-3:Train the model
lr.fit(X_train,y_train)

#Step-4: Predict the model
ypred=lr.predict(X_test)

# %% [markdown]
# # Evaluate the Model

# %%
#Accuracy
from sklearn.metrics import r2_score
r2_score(y_test,ypred)
# Out:
# 0.9999446743407918

# %%
# Errors
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
mean_absolute_error(y_test,ypred)
# Out:
# 0.36424641789396106

# %%
mse=mean_squared_error(y_test,ypred)
mse
# Out:
# 1.1208694197903712

# %%
np.sqrt(mse)
# Out:
# 1.0587112069825138

# %% [markdown]
# # Predicting the Accuracy using LinearRegression

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train,y_train)
ypred = lr.predict(X_test)
r2_score(y_test,ypred)
# Out:
# 0.9999446743407918

# %%
ypred
# Out:
# array([293.09540236,  36.88068949,   7.00088743, ...,  14.04831223,
#         18.50986842, 184.260821  ])

# %% [markdown]
# # Predicting the Accuracy using Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
from sklearn import tree
dt=DecisionTreeRegressor()

# %%
def mymodel(model):
 model.fit(X_train,y_train)
 ypred = model.predict(X_test)
 print(r2_score(y_test,ypred))
 
 return model

# %%
mymodel(dt)
# Out:
# 0.999807547188782
# DecisionTreeRegressor()

# %%
# Max Depth
for i in range(10,25):
 dt1 = DecisionTreeRegressor(max_depth = i)
 dt1.fit(X_train,y_train)
 ypred = dt1.predict(X_test)
 ac = r2_score(y_test,ypred)
 print(f"max_depth = {i} accuracy : {ac}")
# Out:
# max_depth = 10 accuracy : 0.9998514533716221
# max_depth = 11 accuracy : 0.9998173833979714
# max_depth = 12 accuracy : 0.9998272395524634
# max_depth = 13 accuracy : 0.9998259648794705
# max_depth = 14 accuracy : 0.9998240828055446
# max_depth = 15 accuracy : 0.9998210841393235
# max_depth = 16 accuracy : 0.9998601223864335
# max_depth = 17 accuracy : 0.9998157836837103
# max_depth = 18 accuracy : 0.9998071434464306
# max_depth = 19 accuracy : 0.9998542612137801
# max_depth = 20 accuracy : 0.9998123188631475
# max_depth = 21 accuracy : 0.9998535261298813
# max_depth = 22 accuracy : 0.999808836529629
# max_depth = 23 accuracy : 0.9998494602900486
# max_depth = 24 accuracy : 0.9998486012538783

# %%
dt2 = DecisionTreeRegressor(max_depth =24)
mymodel(dt2)
# Out:
# 0.9998111313315903
# DecisionTreeRegressor(max_depth=24)

# %% [markdown]
# # Predicting the Accuracy using Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
rc = RandomForestRegressor()
rc.fit(X_train,y_train)
ypred = rc.predict(X_test)
print(r2_score(y_test,ypred))
# Out:
# 0.9998930790911981

# %% [markdown]
# # Predicting the data using Gradient Boosting Regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbc = GradientBoostingRegressor()
gbc.fit(X_train,y_train)
ypred = gbc.predict(X_test)
print(r2_score(y_test,ypred))
# Out:
# 0.999705197373301

# %% [markdown]
# # Predicting the data using XGBRegressor

# %%
from xgboost import XGBRegressor
xgb = XGBRegressor()
xgb.fit(X_train,y_train)
ypred = xgb.predict(X_test)
print(r2_score(y_test,ypred))
# Out:
# 0.9989124454970262

# %% [markdown]
# # Conclusion

# %% [markdown]
# # Based on the above accuracy scores, we should go ahead with Decision Tree and Randomforest
